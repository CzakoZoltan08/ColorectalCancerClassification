# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from AutoAIAlgorithm.ParticleSwarmOptimization import PSO

import os

# %%
csv_file = os.path.join("colorectal-histology-mnist", "hmnist_8_8_RGB.csv")

# %%
df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        190        117        155        167        115        153
# 1        135         30         53        117         20         47
# 2        169         89        129        172         86        125
# 3        171         58         90        183         66         98
# 4        184        116        151        177        100        138
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0183  pixel0184  \
# 0        157        100        141        168  ...        178         92
# 1        119         30         54        124  ...        126         32
# 2        146         72        117        162  ...        158         89
# 3        150         48         77        181  ...        205         91
# 4        143         72        117        184  ...        181         85
#
#    pixel0185  pixel0186  pixel0187  pixel0188  pixel0189  pixel0190  \
# ...

# %%
df_x = df.drop(df.columns[-1], axis=1)

# %%
df_y = df.iloc[:,-1]

# %%
shape = (8, 8)

# %%
first_row = np.asarray(df_x.iloc[0])

# %%
red_channel = first_row[::3].copy()
green_channel = first_row[1::3].copy()
blue_channel = first_row[2::3].copy()

# %%
red_channel = red_channel.reshape(shape)
green_channel = green_channel.reshape(shape)
blue_channel = blue_channel.reshape(shape)

# %%
img_matrix = np.array([red_channel, green_channel, blue_channel]).T

# %%
img_matrix.shape
# Out:
# (8, 8, 3)

# %%
plt.imshow(img_matrix)

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.15)

# %%
num_particles=5
num_iterations=10

# %%
pso = PSO(particle_count=num_particles, distance_between_initial_particles=0.7, evaluation_metric=accuracy_score)

# %%
best_metric, best_model = pso.fit(X_train=x_train,
                                      X_test=x_test,
                                      Y_train=y_train,
                                      Y_test=y_test,
                                      maxiter=num_iterations,
                                      verbose=True,
                                      max_distance=0.05)
# Out:
# --- START EPOCH 0 ---
# * Parameter=C Value=2.223363364435603 *
# * Parameter=tol Value=1.1801417298718986 *
# * Parameter=intercept_scaling Value=0.18516576842480037 *
# * Parameter=solver Value=newton-cg *
# * Particle 0 Algorithm Type LOGISTIC_REGRESSION: personal best metric=0.572 *
# * Parameter=C Value=1.0070168629981366 *
# * Parameter=tol Value=0.06387624464115592 *
# * Parameter=intercept_scaling Value=0.3380401304018695 *
# * Parameter=solver Value=lbfgs *
# * Particle 1 Algorithm Type LOGISTIC_REGRESSION: personal best metric=0.484 *
# * Parameter=C Value=1.3314360136891599 *
# * Parameter=tol Value=1.4282013813837973 *
# * Parameter=intercept_scaling Value=0.09054890249091596 *
# * Parameter=solver Value=liblinear *
# * Particle 2 Algorithm Type LOGISTIC_REGRESSION: personal best metric=0.3626666666666667 *
# * Parameter=C Value=2.2141410677308264 *
# * Parameter=tol Value=0.4922655082788525 *
# * Parameter=intercept_scaling Value=0.8490838284083343 *
# ...

# %%
best_metric
